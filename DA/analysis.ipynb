# %%
import pandas as pd

# %%
amd_laptop_1024 = pd.read_csv('AMD_laptop_1024.csv')
amd_laptop_1024['expInfo'] = '1024_AMD_laptop'
amd_laptop_1024
# Out:
#               Method  Task Clock (msec)  Context Switches  CPU Migrations  \
# 0              async            1430.31               239              12
# 1             double            1772.15               134               6
# 2               fifo            1416.98               328              18
# 3               lifo            1406.60               386              17
# 4           openBLAS            1970.91              4233              20
# 5             openMP            5378.30             12017              58
# 6  parallel_standard            1416.45               273              11
# 7             single            1515.35               159               6
# 8                tbb            1690.10               533              59
#
#    Page Faults  Instructions       Cycles  Stalled Cycles Frontend  \
# 0         3794    7264135631   6018262098               1295444574
# 1         6732   11645943439   7661581335               1578328692
# 2         3933    7599187483   5923144450               1308233886
# 3         3934    7701963526   5856165613               1281843453
# 4         7881    9368825989   8283376922               1953947814
# 5         4030   20576653993  22085182598               2166923115
# 6         3793    7447362404   5954512169               1291597049
# 7         3663    8246531838   6510720916               1501014233
# 8        20570   10505373807   7144552943               1459054129
#
#      Branches  Branch Misses  L1-dcache Load Misses  Backend Bound  \
# 0  1070719575       98899802              168359364     5983011009
# 1  1944327946      127539109              216400601     7661155611
# 2  1066035573      100669967              174474089     5912977413
# 3  1056129091      101096708              169390449     5850446290
# 4  1840591526      153478565               67747811     8280520839
# 5  4204490149      131015009              454616455    22085940398
# 6  1066039033      100079309              165497336     5937082724
# 7  1198849904      122489221              144485112     6506690448
# 8  1277052754      114230880              151234315     7138507597
#
#    Sched Wakeup  Sched Wakeup New  Elapsed Time (s)          expInfo
# 0            83                23           0.16732  1024_AMD_laptop
# 1            48                15           0.53148  1024_AMD_laptop
# 2           121                31           0.16356  1024_AMD_laptop
# 3           129                31           0.16070  1024_AMD_laptop
# 4          1293                15           0.35457  1024_AMD_laptop
# 5          3527                30           0.39151  1024_AMD_laptop
# 6            71                23           0.16683  1024_AMD_laptop
# 7            95                15           0.29073  1024_AMD_laptop
# 8           152                30           0.20669  1024_AMD_laptop

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot branch instructions
axs[0].bar(amd_laptop_1024['Method'], amd_laptop_1024['Branches'])
axs[0].set_xlabel('Method')
axs[0].set_ylabel('Branch Instructions')
axs[0].set_title('Branch Instructions for Different Methods')
axs[0].tick_params(axis='x', rotation=45)

# Plot branch misses
axs[1].bar(amd_laptop_1024['Method'], amd_laptop_1024['Branch Misses'])
axs[1].set_xlabel('Method')
axs[1].set_ylabel('Branch Misses')
axs[1].set_title('Branch Misses for Different Methods')
axs[1].tick_params(axis='x', rotation=45)

# Plot cache misses
axs[2].bar(amd_laptop_1024['Method'], amd_laptop_1024['L1-dcache Load Misses'])
axs[2].set_xlabel('Method')
axs[2].set_ylabel('Cache Misses')
axs[2].set_title('Cache Misses for Different Methods')
axs[2].tick_params(axis='x', rotation=45)

# Add a title to the entire figure
fig.suptitle('AMD laptop 1024')

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
amd_laptop_4096 = pd.read_csv('AMD_laptop_4096.csv')
amd_laptop_4096['expInfo'] = '4096_AMD_laptop'
amd_laptop_4096
# Out:
#               Method  Task Clock (msec)  Context Switches  CPU Migrations  \
# 0              async           32099.07              3754              56
# 1             double           23937.16               535              43
# 2               fifo           32495.15              3898              51
# 3               lifo           32460.97              6475              53
# 4           openBLAS           14101.72              2430              38
# 5             openMP          107745.14             13870              90
# 6  parallel_standard           32088.99              8374             167
# 7             single           16087.88               520              45
# 8                tbb           53955.58              9024             349
#
#    Page Faults  Instructions        Cycles  Stalled Cycles Frontend  \
# 0        50303  233427763887  129234952758               2570346072
# 1        98989  307425295087  107371336646               3399219943
# 2        50115  232389993637  131603031910               2697975643
# 3        50115  232367191321  130923515836               2636982435
# 4       103096  109721954569   58549067531               6394921372
# 5        50196  598551334867  430647274588              34936193501
# 6        50373  232457807817  130988998012               2821509676
# 7        49833  231277482147   72078032975               2382674416
# 8       985316  397510179398  215647341268               6208209685
#
#       Branches  Branch Misses  L1-dcache Load Misses  Backend Bound  \
# 0  14335259863      162465104             8848922955   129232985464
# 1  33283827214      235936331            13150735618   107372548612
# 2  14343972768      163165371             8849204098   131597559773
# 3  14327563236      161170086             8847389017   130907796242
# 4  15703857349      443755631             3239837818    58544915962
# 5  77225213806      757653930            26504796253   430678464988
# 6  14349003661      164366142             8838021247   130982986542
# 7  14326189276      161714888             8660694840    72081250812
# 8  23996982895      326944098             9238886101   215648040511
#
#    Sched Wakeup  Sched Wakeup New  Elapsed Time (s)          expInfo
# 0          2499                47            3.3621  4096_AMD_laptop
# 1           380                15           22.7940  4096_AMD_laptop
# 2          2771                31            3.3817  4096_AMD_laptop
# 3          2786                31            3.3528  4096_AMD_laptop
# 4           865                15            5.4268  4096_AMD_laptop
# 5          8833                30            8.1529  4096_AMD_laptop
# 6          2567                47            3.3064  4096_AMD_laptop
# 7           899                15           14.9470  4096_AMD_laptop
# 8          5017                30            4.9570  4096_AMD_laptop

# %%
# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot branch instructions
axs[0].bar(amd_laptop_4096['Method'], amd_laptop_4096['Branches'])
axs[0].set_xlabel('Method')
axs[0].set_ylabel('Branch Instructions')
axs[0].set_title('Branch Instructions for Different Methods')
axs[0].tick_params(axis='x', rotation=45)

# Plot branch misses
axs[1].bar(amd_laptop_4096['Method'], amd_laptop_4096['Branch Misses'])
axs[1].set_xlabel('Method')
axs[1].set_ylabel('Branch Misses')
axs[1].set_title('Branch Misses for Different Methods')
axs[1].tick_params(axis='x', rotation=45)

# Plot cache misses
axs[2].bar(amd_laptop_4096['Method'], amd_laptop_4096['L1-dcache Load Misses'])
axs[2].set_xlabel('Method')
axs[2].set_ylabel('Cache Misses')
axs[2].set_title('Cache Misses for Different Methods')
axs[2].tick_params(axis='x', rotation=45)

# Add a title to the entire figure
fig.suptitle('AMD laptop 4096')

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
amd_server_1024 = pd.read_csv('AMD_server_1024.csv')
amd_server_1024['expInfo'] = '1024_AMD_server'
amd_server_1024
# Out:
#               Method  Task Clock (msec)  Context Switches  CPU Migrations  \
# 0              async            3166.95               231              25
# 1             double            3378.10               105               7
# 2               fifo            3149.93               541              37
# 3               lifo            3147.16               511              34
# 4           openBLAS            4120.65              2092               7
# 5             openMP            9633.03             29253             125
# 6  parallel_standard            3172.90               209              21
# 7             single            3239.50               136               7
# 8                tbb            3346.15              1010             107
#
#    Page Faults  Instructions       Cycles  Stalled Cycles Frontend  \
# 0         4343   14240592999  14986286649               7869032083
# 1         7285   18259736216  16124428262               8354187967
# 2         5058   14556631247  14882244674               7852477260
# 3         5058   14498315920  14872303600               7846999223
# 4         8980   17680505674  19570513951              10471818218
# 5         5348   39410959081  45683350191               9026191801
# 6         4343   14358460621  15029898884               7844853000
# 7         4207   14741574654  15131411334               8156094783
# 8        21853   17178834599  15822359646               8127260338
#
#      Branches  Branch Misses  L1-dcache Load Misses  Backend Bound  \
# 0  2528872296      304443136              152388290    14957798160
# 1  3361035368      324162975              193984429    16089085333
# 2  2496568425      304252261              159530753    14867265449
# 3  2493714116      303070135              159367896    14847464594
# 4  3680276534      408348780               56616817    19565731300
# 5  9365439862      332076861              353872582    45616498038
# 6  2532296570      307289173              144072879    14995930130
# 7  2595379729      316062426              142962432    15096034873
# 8  2703880668      312390106              163700008    15796307098
#
#    Sched Wakeup  Sched Wakeup New  Elapsed Time (s)          expInfo
# 0            36                55          0.122149  1024_AMD_server
# 1            30                47          0.369434  1024_AMD_server
# 2           184                95          0.119425  1024_AMD_server
# 3           183                95          0.120069  1024_AMD_server
# 4            40                47          0.239830  1024_AMD_server
# 5           201                94          0.222200  1024_AMD_server
# 6            25                55          0.123787  1024_AMD_server
# 7            38                47          0.225540  1024_AMD_server
# 8           190                93          0.148216  1024_AMD_server

# %%
# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot branch instructions
axs[0].bar(amd_server_1024['Method'], amd_server_1024['Branches'])
axs[0].set_xlabel('Method')
axs[0].set_ylabel('Branch Instructions')
axs[0].set_title('Branch Instructions for Different Methods')
axs[0].tick_params(axis='x', rotation=45)

# Plot branch misses
axs[1].bar(amd_server_1024['Method'], amd_server_1024['Branch Misses'])
axs[1].set_xlabel('Method')
axs[1].set_ylabel('Branch Misses')
axs[1].set_title('Branch Misses for Different Methods')
axs[1].tick_params(axis='x', rotation=45)

# Plot cache misses
axs[2].bar(amd_server_1024['Method'], amd_server_1024['L1-dcache Load Misses'])
axs[2].set_xlabel('Method')
axs[2].set_ylabel('Cache Misses')
axs[2].set_title('Cache Misses for Different Methods')
axs[2].tick_params(axis='x', rotation=45)

# Add a title to the entire figure
fig.suptitle('AMD server 1024')

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
amd_server_4096 = pd.read_csv('AMD_server_4096.csv')
amd_server_4096['expInfo'] = '4096_AMD_server'
amd_server_4096
# Out:
#               Method  Task Clock (msec)  Context Switches  CPU Migrations  \
# 0              async           16664.39               164              31
# 1             double           16025.72               241               8
# 2               fifo           18715.19               284             111
# 3               lifo           18397.48               286             113
# 4           openBLAS           13849.32               254              18
# 5             openMP          110771.10              1295             161
# 6  parallel_standard           16526.09               179              32
# 7             single           12806.82               265               7
# 8                tbb           32189.39              6624             331
#
#    Page Faults  Instructions        Cycles  Stalled Cycles Frontend  \
# 0        50923  239525735291   79491580280               9179794239
# 1        99537  313125667103   80291398537              10299237098
# 2        51201  238465241682   89184406911               9226869419
# 3        51200  238431951354   87672115700               9202549175
# 4       105739  104099462908   66701719377              19309634777
# 5        51475  631833497439  527578276515              13173022362
# 6        50924  238428171182   78880424792               9201738310
# 7        50381  237315056397   66268730462               9169043076
# 8      1101801  409191723142  153092516854              15024579366
#
#       Branches  Branch Misses  L1-dcache Load Misses  Backend Bound  \
# 0  15716184782      351921944             7873511849    79437597216
# 1  34658289496      410988457            10686459129    80265863446
# 2  15711101542      351336007             7933527387    89144748562
# 3  15705719600      351277130             7963416069    87629026881
# 4  18176562938      761030765             1975466845    66754062817
# 5  86697154279      474029780            29510038193   527547241813
# 6  15710374258      350818913             7866582361    78818217339
# 7  15714476203      350993895             7640212998    66233446593
# 8  26478719814      534418483             9041550062   153078876991
#
#    Sched Wakeup  Sched Wakeup New  Elapsed Time (s)          expInfo
# 0            62                79           1.25937  4096_AMD_server
# 1           150                47          13.06435  4096_AMD_server
# 2           150                95           1.38831  4096_AMD_server
# 3           135                95           1.35520  4096_AMD_server
# 4           123                47           3.60624  4096_AMD_server
# 5           606                94           3.04122  4096_AMD_server
# 6            67                79           1.28344  4096_AMD_server
# 7           186                47           9.81961  4096_AMD_server
# 8          1291                94           1.99439  4096_AMD_server

# %%
# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot branch instructions
axs[0].bar(amd_server_4096['Method'], amd_server_4096['Branches'])
axs[0].set_xlabel('Method')
axs[0].set_ylabel('Branch Instructions')
axs[0].set_title('Branch Instructions for Different Methods')
axs[0].tick_params(axis='x', rotation=45)

# Plot branch misses
axs[1].bar(amd_server_4096['Method'], amd_server_4096['Branch Misses'])
axs[1].set_xlabel('Method')
axs[1].set_ylabel('Branch Misses')
axs[1].set_title('Branch Misses for Different Methods')
axs[1].tick_params(axis='x', rotation=45)

# Plot cache misses
axs[2].bar(amd_server_4096['Method'], amd_server_4096['L1-dcache Load Misses'])
axs[2].set_xlabel('Method')
axs[2].set_ylabel('Cache Misses')
axs[2].set_title('Cache Misses for Different Methods')
axs[2].tick_params(axis='x', rotation=45)

# Add a title to the entire figure
fig.suptitle('AMD server 4096')

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
intel_1024 = pd.read_csv('Intel_1024.csv')
intel_1024['expInfo'] = '1024_Intel'
intel_1024
# Out:
#               Method  Task Clock (msec)  Instructions    Branches  \
# 0              async         253.847578    4844409276   444961560
# 1             double        1107.318009    8378923144  1203990590
# 2               fifo         253.509564    4877277714   448865531
# 3               lifo         255.117747    4845541862   443428096
# 4           openBLAS         725.723133    5524312819   961471385
# 5             openMP         490.233685   12057470705  1846415099
# 6  parallel_standard         250.977818    4822473996   440638167
# 7             single         507.035037    5063280243   483325290
#
#    Branch Misses       Cycles  Backend Bound  Stalled Cycles Frontend  \
# 0         796405   4033801247     5199100602               8053751110
# 1        3241495   6047268813     9210657005              11970974098
# 2         776130   4110465631     5244651346               8241145104
# 3         804240   3988879719     5129627607               8031588158
# 4        3651252   5596289493     6847817790              11185514174
# 5        9804980  12429273016    12182133054              24877812888
# 6         731021   3965525865     5097388287               7904316054
# 7         889896   3902517977     5556935777               7691944490
#
#    Elapsed Time (s)  Cache Misses     expInfo
# 0           0.25294       4159998  1024_Intel
# 1           1.10718       7220947  1024_Intel
# 2           0.25337       4083440  1024_Intel
# 3           0.25498       4493704  1024_Intel
# 4           0.72558       6582643  1024_Intel
# 5           0.49010       5168305  1024_Intel
# 6           0.25084       4398743  1024_Intel
# 7           0.50547       3395788  1024_Intel

# %%
# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot branch instructions
axs[0].bar(intel_1024['Method'], intel_1024['Branches'])
axs[0].set_xlabel('Method')
axs[0].set_ylabel('Branch Instructions')
axs[0].set_title('Branch Instructions for Different Methods')
axs[0].tick_params(axis='x', rotation=45)

# Plot branch misses
axs[1].bar(intel_1024['Method'], intel_1024['Branch Misses'])
axs[1].set_xlabel('Method')
axs[1].set_ylabel('Branch Misses')
axs[1].set_title('Branch Misses for Different Methods')
axs[1].tick_params(axis='x', rotation=45)

# Plot cache misses
axs[2].bar(intel_1024['Method'], intel_1024['Cache Misses'])
axs[2].set_xlabel('Method')
axs[2].set_ylabel('Cache Misses')
axs[2].set_title('Cache Misses for Different Methods')
axs[2].tick_params(axis='x', rotation=45)

# Add a title to the entire figure
fig.suptitle('Intel 1024')

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
intel_4096 = pd.read_csv('Intel_4096.csv')
intel_4096['expInfo'] = '4096_Intel'
intel_4096
# Out:
#               Method  Task Clock (msec)  Instructions     Branches  \
# 0              async        8797.029815  229745157502  13519415572
# 1             double       39210.415645  303286807206  32313835418
# 2               fifo        8733.057695  228922596423  13525052887
# 3               lifo        8736.679627  228942978590  13533017719
# 4           openBLAS       12892.745960  100975887909  13605599044
# 5             openMP       20536.985238  586650559499  73876263256
# 6  parallel_standard        8492.628802  228687398606  13520165097
# 7             single       27245.775269  227543744743  13474352999
# 8                tbb       13501.011445  392736729065  22693169858
#
#    Branch Misses        Cycles  Backend Bound  Stalled Cycles Frontend  \
# 0       11620815  161125982687   221332460449             322206428284
# 1       63266173  137689250658   296171345313             275425975498
# 2       11557120  161777044187   221012238084             323483149260
# 3       11867704  161820010537   221056167340             323607949086
# 4       59434203   78644726536   113506086986             157344205844
# 5      554805983  446557515694   532957586238             893080510428
# 6       12182893  163047221831   220878991732             326053312358
# 7        9505409   98061938802   219384605766             196160713450
# 8       29653822  260182339130   430010644013             520413337518
#
#    Elapsed Time (s)  Cache Misses     expInfo
# 0            8.7969     262818785  4096_Intel
# 1           39.2100     808540801  4096_Intel
# 2            8.7329     350264557  4096_Intel
# 3            8.7365     339508284  4096_Intel
# 4           12.8926     824510874  4096_Intel
# 5           20.5370     235886549  4096_Intel
# 6            8.4925     486375696  4096_Intel
# 7           27.2456     194571777  4096_Intel
# 8           13.5009     523519752  4096_Intel

# %%
# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot branch instructions
axs[0].bar(intel_4096['Method'], intel_4096['Branches'])
axs[0].set_xlabel('Method')
axs[0].set_ylabel('Branch Instructions')
axs[0].set_title('Branch Instructions for Different Methods')
axs[0].tick_params(axis='x', rotation=45)

# Plot branch misses
axs[1].bar(intel_4096['Method'], intel_4096['Branch Misses'])
axs[1].set_xlabel('Method')
axs[1].set_ylabel('Branch Misses')
axs[1].set_title('Branch Misses for Different Methods')
axs[1].tick_params(axis='x', rotation=45)

# Plot cache misses
axs[2].bar(intel_4096['Method'], intel_4096['Cache Misses'])
axs[2].set_xlabel('Method')
axs[2].set_ylabel('Cache Misses')
axs[2].set_title('Cache Misses for Different Methods')
axs[2].tick_params(axis='x', rotation=45)

# Add a title to the entire figure
fig.suptitle('Intel 4096')

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
